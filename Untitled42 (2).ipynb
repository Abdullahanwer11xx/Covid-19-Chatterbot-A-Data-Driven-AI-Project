# %% [markdown]
# #

# %% [markdown]
# ***Step 1: Import Libraries***

# %%
import json
import random
import pickle
import tkinter as tk
from tkinter import scrolledtext
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

# %% [markdown]
# ***Step 2: Load the Intents Data***

# %%
# Load the intents data from the JSON file
def load_intents(file_path):
    with open(file_path, 'r') as file:
        return json.load(file)

# %% [markdown]
# ***Step 3: Prepare the Dataset***

# %%
# Prepare the dataset: Convert intents into training data
def prepare_dataset(intents_data):
    texts = []
    labels = []
    for intent in intents_data['intents']:
        for pattern in intent['text']:
            texts.append(pattern)
            labels.append(intent['intent'])
    return texts, labels

# %% [markdown]
# ***Step 4: Train the Model***

# %%
# Train the model using Naive Bayes classifier
def train_model(texts, labels):
    vectorizer = CountVectorizer()
    X = vectorizer.fit_transform(texts)
    X_train, X_test, y_train, y_test = train_test_split(X, labels, test_size=0.2, random_state=42)

    model = MultinomialNB()
    model.fit(X_train, y_train)

    # Evaluate the model
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    print(f"Model trained with accuracy: {accuracy:.2f}")
    print("\nClassification Report:")
    print(classification_report(y_test, y_pred))

    # Save the model and vectorizer
    with open('model.pkl', 'wb') as model_file:
        pickle.dump(model, model_file)

    with open('vectorizer.pkl', 'wb') as vectorizer_file:
        pickle.dump(vectorizer, vectorizer_file)

    # Plot confusion matrix
    conf_matrix = confusion_matrix(y_test, y_pred, labels=model.classes_)
    plt.figure(figsize=(10, 8))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=model.classes_, yticklabels=model.classes_)
    plt.title("Confusion Matrix")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.show()

    # Plot accuracy graph
    plt.figure(figsize=(10, 5))
    plt.plot([accuracy], marker='o', color='blue', label='Model Accuracy')
    plt.title("Model Accuracy Over Training")
    plt.ylabel("Accuracy")
    plt.xlabel("Epochs")
    plt.legend()
    plt.show()

    # Plot word frequency graph
    plot_word_frequency(texts)

def plot_word_frequency(texts):
    words = ' '.join(texts).split()
    word_freq = Counter(words)
    common_words = word_freq.most_common(20)
    words, frequencies = zip(*common_words)
    plt.figure(figsize=(10, 6))
    plt.bar(words, frequencies, color='skyblue')
    plt.xticks(rotation=90)
    plt.xlabel('Words')
    plt.ylabel('Frequency')
    plt.title('Top 20 Most Frequent Words in the Dataset')
    plt.show()

# %% [markdown]
# ***Step 5: Generate Responses Based on Intent***

# %%
# Function to generate a response based on user input
def get_response(intent):
    responses = {
        'greeting': [
            "Hello! How can I assist you today?", "Hi there! How can I help you?", "Greetings! How can I help you today?",
            "Hey there! What can I do for you?", "Howdy! How may I assist you?"
        ],
        'covid_origin': [
            "COVID-19 originated in Wuhan, China, in December 2019.",
            "COVID-19 first appeared in Wuhan, China, and quickly spread globally.",
            "The virus that caused COVID-19 was first detected in Wuhan, China, in late 2019."
        ],
        'covid_deaths': [
            "As of now, millions have died due to COVID-19 worldwide.",
            "The global death toll from COVID-19 has reached millions.",
            "The death toll from COVID-19 has exceeded millions globally."
        ],
        'covid_business_loss': [
            "COVID-19 caused massive economic losses globally, with businesses shutting down and many industries severely impacted.",
            "The pandemic resulted in extensive economic losses, disrupting businesses worldwide.",
            "COVID-19's economic impact led to closures of businesses and severe losses in various sectors."
        ],
        'covid_age_comparison': [
            "COVID-19 is more dangerous for older adults compared to younger people.",
            "Older individuals, especially those with underlying conditions, are more vulnerable to severe COVID-19 outcomes.",
            "The elderly are at a higher risk of severe illness or death from COVID-19 compared to younger populations."
        ],
        'covid_prone_group': [
            "People with underlying health conditions, older adults, and those with compromised immune systems are more prone to severe illness from COVID-19.",
            "Older adults and individuals with pre-existing health conditions are at greater risk for contracting and suffering severe effects of COVID-19.",
            "Individuals with certain health conditions, like heart disease or diabetes, are more vulnerable to COVID-19."
        ],
        'covid_pakistan_deaths': [
            "As of the latest reports, over 30,000 people have died from COVID-19 in Pakistan.",
            "The death toll from COVID-19 in Pakistan has surpassed 30,000, with ongoing impacts."
        ],
        'covid_business_impact_pakistan': [
            "COVID-19 led to significant economic losses in Pakistan, with many businesses being forced to close temporarily or permanently.",
            "The pandemic severely disrupted Pakistan’s economy, causing widespread business closures and losses."
        ],
        'covid_transmission': [
            "COVID-19 spreads primarily through respiratory droplets when an infected person coughs, sneezes, or talks.",
            "The virus can spread via the air, especially in crowded or poorly ventilated spaces.",
            "COVID-19 can be transmitted through droplets, close contact, and potentially by touching contaminated surfaces."
        ],
        'covid_effect_on_body': [
            "COVID-19 can affect various parts of the body, including the lungs, heart, and kidneys. It primarily affects the respiratory system.",
            "The virus can lead to severe lung damage, heart problems, and, in some cases, long-term health issues.",
            "COVID-19 can cause respiratory distress, organ damage, and long-term symptoms, known as 'long COVID'."
        ],
        'covid_prevention': [
            "To prevent COVID-19, wash hands regularly, wear a mask, and practice social distancing.",
            "Preventive measures include wearing masks, maintaining physical distance, and getting vaccinated.",
            "To avoid COVID-19, it's essential to follow hygiene protocols and avoid crowded places."
        ],
        'covid_vaccine': [
            "The COVID-19 vaccine helps prevent severe illness caused by the virus and has shown to be effective against various strains.",
            "COVID-19 vaccines are safe and effective in preventing severe outcomes of the disease.",
            "Getting vaccinated against COVID-19 is crucial for protecting yourself and others from the virus."
        ],
        'covid_testing': [
            "COVID-19 tests, such as PCR and rapid antigen tests, help identify if someone is infected.",
            "You can get tested for COVID-19 at local health centers, hospitals, or through home testing kits.",
            "COVID-19 tests are widely available, and getting tested is important if you've been exposed or have symptoms."
        ],
        'covid_isolation': [
            "You should isolate for at least 5 days if you test positive for COVID-19, even if you're asymptomatic.",
            "During isolation, stay away from others, and follow the guidelines provided by health authorities.",
            "Isolate at home if you have COVID-19, and avoid contact with family members or others in your household."
        ],
        'goodbye': [
            "Goodbye! Stay safe!", "Take care! See you later.", "Goodbye! Wishing you well!",
            "Farewell! Stay healthy!", "See you! Take care of yourself!"
        ],
        'unknown_response': [
            "Sorry, I didn't quite understand that. Can you ask something else?",
            "I'm not sure about that. Could you clarify?",
            "I didn't understand that. Please try asking in a different way."
        ]
    }
    return random.choice(responses.get(intent, responses['unknown_response']))

# %% [markdown]
# ***Step 6: Predict Intent Based on User Input***

# %%
# Function to predict the intent and return a response
def predict_intent(model, vectorizer, user_input):
    user_input_transformed = vectorizer.transform([user_input])
    prediction = model.predict(user_input_transformed)
    intent = prediction[0]
    return get_response(intent)

# %% [markdown]
# ***Step 7: Build the GUI for the Chatbot***

# %%
# Create the GUI for the chatbot
class ChatbotGUI:
    def __init__(self, root, model, vectorizer):
        self.root = root
        self.root.title("COVID-19 Medical Chatbot")
        self.model = model
        self.vectorizer = vectorizer
        self.chat_history = scrolledtext.ScrolledText(root, wrap=tk.WORD, state=tk.DISABLED, width=60, height=20)
        self.chat_history.grid(row=0, column=0, padx=10, pady=10)
        self.entry_box = tk.Entry(root, width=50)
        self.entry_box.grid(row=1, column=0, padx=10, pady=10)
        self.send_button = tk.Button(root, text="Send", width=20, command=self.send_message)
        self.send_button.grid(row=1, column=1, padx=10, pady=10)

    def send_message(self):
        user_input = self.entry_box.get()
        if user_input.lower() == 'exit':
            self.chat_history.config(state=tk.NORMAL)
            self.chat_history.insert(tk.END, "Goodbye!\n")
            self.chat_history.config(state=tk.DISABLED)
            self.root.destroy()  # Gracefully close the window
            return

        # Display user input in the chat history
        self.chat_history.config(state=tk.NORMAL)
        self.chat_history.insert(tk.END, f"You: {user_input}\n")
        self.chat_history.config(state=tk.DISABLED)

        # Get the bot's response
        response = predict_intent(self.model, self.vectorizer, user_input)

        # Display bot's response in the chat history
        self.chat_history.config(state=tk.NORMAL)
        self.chat_history.insert(tk.END, f"Bot: {response}\n")
        self.chat_history.config(state=tk.DISABLED)

        # Clear the entry box
        self.entry_box.delete(0, tk.END)

# %% [markdown]
# ***Step 8: Main Function to Load Data, Train Model, and Start GUI***

# %%
# Load the trained model and vectorizer
def load_model_and_vectorizer():
    with open('model.pkl', 'rb') as model_file:
        model = pickle.load(model_file)
    with open('vectorizer.pkl', 'rb') as vectorizer_file:
        vectorizer = pickle.load(vectorizer_file)
    return model, vectorizer

# %% [markdown]
# ***Step 9: Add load_model_and_vectorizer Function***

# %%
# Main function to load data, train the model, and start the GUI
if __name__ == "__main__":
    # Load the intents data
    intents_file = r'C:\Users\UAE\Downloads\create_chatbot_using_python-main\create_chatbot_using_python-main\intents.json'  
    intents_data = load_intents(intents_file)

    # Prepare the dataset
    texts, labels = prepare_dataset(intents_data)

    # Train the model
    train_model(texts, labels)

    # Load the trained model and vectorizer
    model, vectorizer = load_model_and_vectorizer()

    # Create the main window for the GUI
    root = tk.Tk()

    # Initialize the chatbot GUI
    chatbot_gui = ChatbotGUI(root, model, vectorizer)

    # Run the GUI
    root.mainloop()
# Out:
# Model trained with accuracy: 0.58
#
# Classification Report:
#                                 precision    recall  f1-score   support
#
#           covid_age_comparison       1.00      0.50      0.67         2
# covid_business_impact_pakistan       0.00      0.00      0.00         0
#            covid_business_loss       0.00      0.00      0.00         1
#                   covid_deaths       0.67      0.67      0.67         3
#           covid_effect_on_body       0.50      0.50      0.50         2
#                covid_isolation       1.00      0.67      0.80         3
#                   covid_origin       1.00      1.00      1.00         3
#          covid_pakistan_deaths       1.00      0.67      0.80         3
#               covid_prevention       1.00      1.00      1.00         1
#              covid_prone_group       1.00      1.00      1.00         1
#                  covid_testing       0.20      1.00      0.33         1
# ...
